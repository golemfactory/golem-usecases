# %%
from torch.optim import Adam
import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
from torch import Tensor
from torch import LongTensor

# %%
torch.manual_seed(1000)
# torch.backends.cudnn.enabled = False # disables CUDNN non-determinism
# torch.cuda.manual_seed(1000) # if we are training on gpu

# %%
BATCH_SIZE = 10
NUM_CLASSES = 10

# %%
arch = "CPU"

# %%
class Net(nn.Module):

    def __init__(self):
        super().__init__()
        # 1 input image channel, 6 output channels, 5x5 square convolution
        # kernel
        self.conv1 = nn.Conv2d(1, 6, 5)
        self.conv2 = nn.Conv2d(6, 16, 5)
        # an affine operation: y = Wx + b
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, NUM_CLASSES)

    def forward(self, x):
        # Max pooling over a (2, 2) window
        x = F.max_pool2d(F.relu(self.conv1(x)), (2, 2))
        # If the size is a square you can only specify a single number
        x = F.max_pool2d(F.relu(self.conv2(x)), 2)
        x = x.view(-1, self.num_flat_features(x))
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

    def num_flat_features(self, x):
        size = x.size()[1:]  # all dimensions except the batch dimension
        num_features = 1
        for s in size:
            num_features *= s
        return num_features


net = Net()
print(net)
# Out:
# Net (
#   (conv1): Conv2d(1, 6, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear (400 -> 120)
#   (fc2): Linear (120 -> 84)
#   (fc3): Linear (84 -> 10)
# )

# %%
optimizer = Adam(net.parameters())
crit = nn.CrossEntropyLoss()

# %%
for epoch in range(10):
    for minibatch_num in range(10):
        batch_x = Variable(torch.randn(BATCH_SIZE, 1, 32, 32))
        batch_y = Variable(LongTensor(BATCH_SIZE).random_(NUM_CLASSES))
        optimizer.zero_grad()
        out = net(batch_x)
        loss = crit(out, batch_y)
        loss.backward()
        optimizer.step()

# %%
CHECKPOINT_NAME = "check2.pth.tar"

# %%
def save_checkpoint(state, filename=CHECKPOINT_NAME):
    torch.save(state, filename)

# %%
save_checkpoint({
    'epoch': epoch + 1,
    'minibatch': minibatch_num,
    'arch': arch,
    'state_dict': net.state_dict(),
    'optimizer' : optimizer.state_dict(),
})

# %% [markdown]
# ### Resuming

# %%
checkpoint1 = torch.load("check1.pth.tar")
# start_epoch1 = checkpoint['epoch']
# net.load_state_dict(checkpoint['state_dict'])
# optimizer.load_state_dict(checkpoint['optimizer'])

# %%
checkpoint2 = torch.load("check2.pth.tar")
# start_epoch1 = checkpoint['epoch']
# net.load_state_dict(checkpoint['state_dict'])
# optimizer.load_state_dict(checkpoint['optimizer'])

# %%
for k in checkpoint1.keys():
    if hasattr(checkpoint1[k], "__iter__"):
        for x, y in zip(checkpoint1[k], checkpoint2[k]):
            print("a")
            print(x == y)
    else:
        print("a")
        print(x == y)
# Out:
# a
# True
# a
# True
# a
# True
# a
# True
# a
# True
# a
# True
# a
# True
# a
# True
# a
# True
# a
# True
# a
# True
# a
# True
# a
# True
# a
# True
# a
# True
# a
# True
# a
# True

# %%
checkpoint2["state_dict"]
# Out:
# OrderedDict([('conv1.weight',
#               (0 ,0 ,.,.) =
#                 0.0459 -0.0957 -0.1438  0.0353  0.1765
#                -0.1957 -0.0230 -0.0557  0.1446  0.1391
#                -0.1072 -0.1745 -0.1753 -0.0568 -0.0291
#                -0.1190 -0.0982  0.1426  0.1327  0.0398
#                -0.0962  0.0867  0.0861  0.1489 -0.0354
#
#               (1 ,0 ,.,.) =
#                -0.1695 -0.1063 -0.1856  0.1036  0.1507
#                -0.1613  0.1193  0.1555 -0.1622  0.1716
#                 0.1310  0.1708 -0.1047 -0.0360  0.0709
#                -0.1911 -0.0087  0.1839  0.1247 -0.0659
#                -0.1008  0.0836  0.0143 -0.0502  0.1418
#
#               (2 ,0 ,.,.) =
#                -0.1809  0.1400  0.1396 -0.1633  0.0681
#                 0.0236  0.1100  0.1405  0.0320 -0.1052
#                 0.1340 -0.2007  0.1560  0.0405 -0.1908
#                 0.1879 -0.1800  0.0832 -0.0926  0.0919
#                -0.1366 -0.1788  0.0962 -0.0862 -0.0380
#
#               (3 ,0 ,.,.) =
#                 0.0923  0.1425 -0.1507 -0.1111  0.1171
#                -0.0215 -0.1157 -0.1791 -0.0182  0.0700
#                 0.1254 -0.0127 -0.1164 -0.1382  0.1779
#                 0.1465  0.1468  0.1485 -0.0726 -0.1528
#                 0.0510 -0.1728  0.0425 -0.0303  0.0442
#
#               (4 ,0 ,.,.) =
#                 0.0286 -0.1667 -0.0752  0.0683  0.0714
#                 0.1692 -0.1168 -0.0950  0.0108 -0.1090
#                 0.0106  0.1639 -0.0212 -0.1623 -0.1458
#                 0.1437 -0.1173  0.1646 -0.1339 -0.0545
#                -0.0709 -0.1805 -0.1105 -0.1098  0.0146
#
#               (5 ,0 ,.,.) =
#                -0.1921  0.0135 -0.0250 -0.0399 -0.1643
#                -0.0881 -0.0722  0.0117 -0.1534  0.1470
#                 0.1182  0.1507  0.1116 -0.1542 -0.1745
#                -0.0762 -0.0132 -0.0237 -0.1199  0.1004
#                -0.0356  0.0901  0.1309 -0.0152 -0.0911
#               [torch.FloatTensor of size 6x1x5x5]), ('conv1.bias',
#               -0.0453
#               -0.0605
#                0.1218
#               -0.0726
#                0.0164
#                0.1560
#               [torch.FloatTensor of size 6]), ('conv2.weight',
#               (0 ,0 ,.,.) =
#               1.00000e-02 *
#                 5.8035 -0.9858 -7.9923  6.7734 -3.0128
#                 6.5112  6.6791 -1.0249  2.4064  0.0906
#                 5.4684 -8.1180 -4.8567  4.0409  3.0941
#                 2.9967 -6.0846  2.3252 -0.2089  3.8315
#                -5.4066  1.1864 -1.3627  7.0964  4.0396
#
#               (0 ,1 ,.,.) =
#               1.00000e-02 *
#                -7.0532 -4.4859 -2.4841  1.4974  3.7898
#                -2.0963 -1.3382  5.7269  2.1582  1.4125
#                -2.6865  1.6820  5.7851 -2.9701 -4.4560
#                -0.6329 -8.8733 -8.1629  0.8868 -7.3607
#                 0.3443  5.8506  1.2450 -8.1011 -8.7213
#
#               (0 ,2 ,.,.) =
#               1.00000e-02 *
#                 6.1980  2.0313  2.5612  1.4741  0.6348
#                -0.0058  2.8176 -7.9379 -6.5479 -3.9736
#                 3.8885  3.9261  2.8109  1.8380 -0.1957
#                -7.5359 -1.1069 -5.0795 -1.1104 -3.9976
#                -1.3751 -7.2379  4.2170  1.5000 -3.8022
#
#               (0 ,3 ,.,.) =
#               1.00000e-02 *
#                -6.8958 -8.2745  5.2436  6.9789 -5.4233
#                -1.7333 -0.0881  3.1368  6.4793  2.1416
#                -8.2246  0.0660 -4.5517 -6.7188  6.1031
#                -4.9129 -8.5929 -1.6999 -4.8825  0.5933
#                 7.5417  4.3031  0.4696 -3.9532 -6.0157
#
#               (0 ,4 ,.,.) =
#               1.00000e-02 *
#                -2.2626 -4.1125  5.3198  4.2662  4.5843
#                -8.5960 -7.2374  5.2785 -7.0240 -8.5770
#                 1.1819 -8.6100  0.1495  4.7689  6.6952
#                 3.6887  3.1588  0.8937  4.3284 -1.7822
#                -5.6989 -2.5432 -0.9973 -6.0382  1.3407
#
#               (0 ,5 ,.,.) =
#               1.00000e-02 *
#                -5.0072 -9.0306 -4.9666 -0.3158  4.3997
#                -1.9153  5.6005 -3.3982  0.7407 -4.8295
#                 4.5548  5.6214  2.2064 -8.7520  1.4973
#                -4.0179  2.7771 -4.2859 -1.8239  6.7942
#                 4.8943 -8.6769 -0.0797 -1.7184 -2.8688
#                    ⋮
#
#               (1 ,0 ,.,.) =
#               1.00000e-02 *
#                -2.8902 -4.1865  2.5518  1.8527  2.8632
#                -5.9311  2.0255 -1.1970  6.2231 -5.6692
#                 6.5504 -5.5954 -7.6652 -5.6817 -6.1838
#                 1.1435 -8.9266 -8.7664  6.7594  0.8950
#                 7.2661 -0.8237 -2.1742  4.6932 -7.4563
#
#               (1 ,1 ,.,.) =
#               1.00000e-02 *
#                -0.7356 -6.5907 -8.9759  5.4042  2.6250
#                -1.2687 -8.0701 -5.3590 -6.6125  1.2059
#                -0.3662  3.7752  3.6272 -0.8532 -6.0164
#                -7.7476  0.5103 -2.6540 -5.6380  5.7572
#                -2.4945 -7.4290 -2.9522 -6.5909  5.5602
#
#               (1 ,2 ,.,.) =
#               1.00000e-02 *
#                 4.2235 -6.8268 -6.2432  0.2364 -6.1279
#                -7.8004 -4.8024  2.5938 -4.0703 -0.1324
#                -3.0064  0.4268  3.9163 -1.4462 -4.3066
#                -0.6876 -6.8002 -0.1866 -6.4986 -1.8027
#                -2.9420  1.0819 -4.8057 -2.8160  5.2178
#
#               (1 ,3 ,.,.) =
#               1.00000e-02 *
#                -1.2155  1.4867 -2.4096 -3.8361 -6.3033
#                 7.8144  4.2417 -1.6614  2.1040  6.1728
#                -4.9600 -3.8906 -4.1878 -3.6155 -3.4012
#                 7.0993  7.0724 -7.0625 -7.8874  5.4449
#                 2.8882  6.9769  7.7002 -3.2887  5.8915
#
#               (1 ,4 ,.,.) =
#               1.00000e-02 *
#                 5.8882 -5.2313  6.0712  5.7034  8.0202
#                 0.1809 -6.2836 -8.1790  1.0544  5.6836
#                 3.9264 -5.3598  3.2674  1.2894  5.0954
#                 1.8640 -8.3703  3.1502  6.6230  2.7560
#                -6.0803 -6.7115 -8.3741 -5.5771  7.2702
#
#               (1 ,5 ,.,.) =
#               1.00000e-02 *
#                 0.9899 -5.9329  1.9551  5.1243  3.8755
#                -8.1517  5.5170 -8.1315  5.6433 -7.3830
#                 2.2276  1.9649 -2.4691 -4.7670 -5.6177
#                -1.6655 -3.5027  7.2514  3.3561 -5.4551
#                -4.5841 -4.7512  2.7585 -0.8882 -3.1464
#                    ⋮
#
#               (2 ,0 ,.,.) =
#               1.00000e-02 *
#                -4.4230 -9.1417 -0.0018  4.9694 -1.4292
#                -1.8437 -3.0851  4.1747 -9.4702  3.5073
#                 3.6059  5.3152  5.2893  5.4373 -1.8373
#                 0.4210 -1.3767  5.7522 -8.0013  0.9729
#                 3.9983 -2.0814 -5.1256 -3.6408 -5.9609
#
#               (2 ,1 ,.,.) =
#               1.00000e-02 *
#                 6.6872 -6.3406 -1.0850 -5.3789 -4.4822
#                 2.6733 -2.5389 -1.8353  5.6045  2.2482
#                -1.3124 -6.9733 -2.4623 -5.5199  0.3339
#                 4.7159  4.0815 -8.5471  5.3214 -5.1750
#                 0.0240  5.0503 -0.5017  1.9101 -4.0439
#
#               (2 ,2 ,.,.) =
#               1.00000e-02 *
#                -3.8599 -8.5786  4.4719  6.9039 -5.9858
#                -6.3319 -0.4613 -6.9978  0.6442 -2.0281
#                 7.2258 -7.2107  2.1804  1.7598 -2.9605
#                -5.0021 -0.4674  4.1976 -4.6012 -6.1994
#                 7.5919  4.5829 -1.8500 -6.5193 -7.5796
#
#               (2 ,3 ,.,.) =
#               1.00000e-02 *
#                -4.5056  7.3018  0.5468  5.8087 -3.1762
#                -0.2286  8.1161 -8.0149  4.5629  5.0013
#                 2.8154  5.9154 -6.8028  1.8175  2.8760
#                -4.0505 -4.9326  6.4378  3.1798 -8.7970
#                 7.0080 -3.8017 -0.2080 -3.0773  2.8888
#
#               (2 ,4 ,.,.) =
#               1.00000e-02 *
#                 5.0518  1.2779 -8.8216 -0.1201  1.2853
#                -0.3770  0.2402  3.3446 -3.7063  0.4155
#                -7.3708  2.0087 -6.6501 -1.8737  1.7505
#                -1.3155 -8.2627  7.4931 -7.4029 -7.5107
#                -1.2825 -3.3691 -0.5440 -4.4249 -8.7693
#
#               (2 ,5 ,.,.) =
#               1.00000e-02 *
#                 1.0527 -0.1244 -4.6642 -7.1312 -6.7835
#                -6.6899 -5.8233  3.5377 -0.3460 -4.0915
#                -1.2032  3.5245 -6.9046  7.3525 -1.3196
#                 1.5922  6.1775  7.3614 -0.6538 -2.8266
#                -4.6701 -2.0626 -1.4975 -1.7208  0.4598
#               ...
#                    ⋮
#
#               (13,0 ,.,.) =
#               1.00000e-02 *
#                 7.3998 -7.7330 -6.8895  3.0049 -6.0470
#                -0.8519 -8.0048  6.5749  6.1259 -4.5544
#                -7.2963  5.6806 -4.4122 -6.1635 -5.2146
#                -4.1903 -2.0417  0.2631 -0.7939 -3.6717
#                -6.5597  4.8065  3.1174 -2.7498  5.2547
#
#               (13,1 ,.,.) =
#               1.00000e-02 *
#                 1.4542  1.3601 -8.4703 -1.1347  1.4735
#                -6.5027 -4.1158 -8.1812 -0.7330 -5.3953
#                 0.1581  4.7622  2.7231 -7.7756  3.6398
#                -8.2157  6.8760  0.1514 -7.5272 -1.2387
#                 3.2935  6.3762  3.5329 -3.3364  2.9828
#
#               (13,2 ,.,.) =
#               1.00000e-02 *
#                 4.9194 -3.2248  1.5185 -3.8903  2.8848
#                -2.2984 -0.5384 -2.8242  4.9529 -3.8584
#                -5.4618 -4.3660  7.9799 -0.3747  4.2778
#                 1.3226  2.0948 -1.3947 -5.1365  1.9904
#                 5.6338 -4.9856 -0.7983  6.7166 -5.6737
#
#               (13,3 ,.,.) =
#               1.00000e-02 *
#                 7.8870  5.6252 -8.4401 -8.1563 -6.0696
#                 6.7537  0.8320  2.9968 -3.3104  4.1987
#                 3.7549  2.6444  6.0228 -4.3098  4.7770
#                 6.9495  7.9337 -5.6316 -6.7976 -0.6340
#                -4.1642  7.5575 -5.9187 -3.9750 -3.5761
#
#               (13,4 ,.,.) =
#               1.00000e-02 *
#                -2.4651 -6.4972  0.7080  6.7832  7.9141
#                 0.7757  4.8532  7.0749  2.8705  2.6064
#                 5.6679  6.4307  1.2340 -5.4128  1.0260
#                -1.8449 -7.3424  1.0759 -7.6208 -4.1774
#                 7.0736  1.9592  8.8228 -6.1451  5.4592
#
#               (13,5 ,.,.) =
#               1.00000e-02 *
#                 3.9752  1.4665  4.9867 -3.7167 -2.7237
#                 1.4475 -2.5729 -4.5350  1.1882  3.9227
#                 3.3646 -3.6847  7.2543 -8.0398 -6.9707
#                -7.3836  4.8050 -1.6013 -3.8198  5.4115
#                -4.8264  5.7476 -5.2655  0.1973 -3.8237
#                    ⋮
#
#               (14,0 ,.,.) =
#               1.00000e-02 *
#                -7.1647 -0.6537 -0.0475 -4.6486 -3.7489
#                 5.0784  5.4723 -8.1098  4.7485  0.5717
#                 0.6848 -6.0306  0.4729 -4.6065  7.1609
#                -6.2189  1.2410 -7.1546 -3.9993  1.3252
#                 6.2712  6.8093  5.9921 -8.3247  6.2068
#
#               (14,1 ,.,.) =
#               1.00000e-02 *
#                 6.2992  6.6605  5.0353 -5.5204 -0.3412
#                 0.6322  3.4773  3.5054 -2.2826 -6.8612
#                 2.7415 -5.0595  6.7447 -7.9303 -3.0158
#                -2.8873 -8.5640 -8.2269  6.1841 -0.9269
#                 5.5720  3.7923 -3.9102  6.2797 -6.2873
#
#               (14,2 ,.,.) =
#               1.00000e-02 *
#                -4.9381 -1.1184  1.7700 -5.0881  6.0233
#                -2.7942  7.4912 -0.4704  2.1764  2.6599
#                -7.0250 -5.0301 -0.5650 -5.3910 -7.9991
#                 0.8513 -3.0545 -4.4634 -6.8999 -6.5944
#                 5.9129  5.1357 -4.4538 -7.4691  5.1255
#
#               (14,3 ,.,.) =
#               1.00000e-02 *
#                -0.8650 -2.5960 -0.0071 -8.2807 -4.6269
#                -0.4943  6.8741 -0.1933 -8.4851 -1.9344
#                -7.7156  0.9467 -0.2646  4.4759  2.6434
#                -1.5498  2.4337  3.0903  5.6202 -2.7593
#                -7.2102  4.5893  4.4909 -5.6142  1.7786
#
#               (14,4 ,.,.) =
#               1.00000e-02 *
#                -4.1987  1.8913  0.6596  4.0765 -6.0919
#                -8.3216 -6.0633 -0.9349 -4.1821 -5.5551
#                 1.0932 -7.5536  2.2382  0.5486 -6.4778
#                 1.0849  4.1958 -5.3159  6.1533  2.6273
#                -3.9435 -5.2349  4.8996 -0.1138  5.4702
#
#               (14,5 ,.,.) =
#               1.00000e-02 *
#                -1.1798  5.9004  2.8387 -4.2263  4.2019
#                 6.1295  0.2590  4.3319 -6.6282  3.5880
#                 0.1667 -3.2676  5.5536 -6.3693 -8.1249
#                -4.7104  1.5601  4.0726  0.1457 -4.9161
#                -2.3230 -1.2946  3.6801 -1.2135  1.2421
#                    ⋮
#
#               (15,0 ,.,.) =
#               1.00000e-02 *
#                -0.7751 -3.3093 -3.4917 -4.8749  1.9300
#                 5.8688  5.4887  4.2863  2.5815  6.5526
#                -9.4603 -2.4782 -9.0742  6.8164  2.2667
#                -4.7703 -0.3562 -7.9121  6.5915 -3.8332
#                 3.4782  3.6154  5.0901 -6.3383 -6.2347
#
#               (15,1 ,.,.) =
#               1.00000e-02 *
#                 5.7090  3.7980  1.8287  6.0286  0.6875
#                -3.0105 -4.8662 -6.4589 -0.7179  0.0088
#                -8.8989 -1.1483 -8.4060  3.1152  2.2188
#                 5.9269  2.3630 -1.7692  4.4611 -3.3414
#                 1.0748 -5.4421  5.1248  6.4104  1.2781
#
#               (15,2 ,.,.) =
#               1.00000e-02 *
#                -2.1816  2.9875 -5.6657 -2.5881 -8.1393
#                 6.8111  0.3922 -3.8016 -4.8362  4.7641
#                -6.2322 -8.9604  2.1190  6.5626  4.6441
#                -6.5129  3.4721  4.4457 -5.6911  2.7384
#                 2.2017 -5.0415  4.7326 -4.3835  1.3149
#
#               (15,3 ,.,.) =
#               1.00000e-02 *
#                 4.7449  5.0287 -3.8567  2.3940  2.8333
#                -9.6381  4.3566  0.2165  4.2753  6.2219
#                -1.7460  2.9528 -5.9275 -0.9758 -7.7559
#                 5.2628  0.6266  3.8100  5.7193  1.3188
#                 7.0373  3.7970 -4.8355 -2.8021  5.1398
#
#               (15,4 ,.,.) =
#               1.00000e-02 *
#                 6.1744  2.2497 -7.2901  1.4664  4.9507
#                 0.7956 -2.9134  4.7104  1.5234 -5.8228
#                 1.4563  1.8962 -3.9091  3.7423 -0.0981
#                -1.4447 -6.0045  1.9809 -1.0821 -3.2532
#                 6.3635  0.1518 -4.7614  1.1112 -2.9005
#
#               (15,5 ,.,.) =
#               1.00000e-02 *
#                 5.5311 -1.6881 -2.8072 -4.5980 -2.8634
#                -2.0686 -0.7450 -4.7624  5.4995  1.4893
#                -2.7001 -0.3654  3.3806  0.9443 -7.5956
#                -0.3157  0.8209 -8.7180 -6.1959 -3.4646
#                -5.4697  4.3069 -3.1557 -3.0192  4.7821
#               [torch.FloatTensor of size 16x6x5x5]), ('conv2.bias',
#               1.00000e-02 *
#                -6.0745
#                -2.9145
#                 5.5026
#                -5.6167
#                 5.7409
#                 4.2480
#                -0.6988
#                -4.2244
#                 3.1959
#                -7.6547
#                 3.8443
#                -0.1463
#                 6.5517
#                 6.2081
#                -5.6143
#                -2.8067
#               [torch.FloatTensor of size 16]), ('fc1.weight',
#               1.00000e-02 *
#               -0.4187  1.1229  1.2735  ...  -2.8747 -3.4443 -3.6800
#               -3.9969 -1.2906  3.4205  ...  -3.0741  2.1238 -4.8731
#                0.6786 -3.2344 -3.6555  ...  -1.5540  5.8479  3.6824
#                         ...             ⋱             ...
#                2.1755  4.1792  3.1311  ...  -4.0350  1.3002  2.3196
#               -2.6627  3.4389  3.0529  ...   2.4241 -2.2693 -3.9160
#               -2.0611  1.1039  1.1121  ...  -0.4726  1.6962 -2.9722
#               [torch.FloatTensor of size 120x400]), ('fc1.bias',
#               1.00000e-02 *
#                -4.3380
#                 1.7252
#                 1.7311
#                 3.8803
#                -0.2765
#                -4.4696
#                 2.8358
#                -2.5936
#                 2.8413
#                 4.9608
#                 3.6775
#                -1.4694
#                -2.1337
#                -0.7208
#                 2.3244
#                -3.2436
#                 1.7025
#                 1.6033
#                -3.5464
#                -3.8590
#                 3.2918
#                 2.8363
#                -2.3982
#                 0.8908
#                 0.4975
#                -2.8415
#                 3.0495
#                -4.7726
#                 2.8613
#                 0.6370
#                 2.1380
#                 2.5585
#                -2.7985
#                -3.0029
#                 0.6918
#                -3.6100
#                 0.5929
#                -3.0585
#                 3.4208
#                -0.5304
#                -1.2932
#                -2.7086
#                 4.2570
#                 1.2624
#                 3.5705
#                -1.8445
#                -0.2314
#                -2.0299
#                 5.9088
#                 0.0234
#                -3.2751
#                -5.2946
#                -5.0044
#                 2.9392
#                 3.3480
#                -4.5698
#                 5.7701
#                -1.2649
#                -1.3987
#                -3.6920
#                -3.2882
#                 2.4780
#                 0.3139
#                 0.5954
#                -1.0563
#                -5.6822
#                 0.0800
#                 2.7553
#                 4.6491
#                 0.9950
#                 1.8505
#                -0.8800
#                -1.8187
#                 1.7653
#                -3.2038
#                 1.5042
#                -3.8686
#                 3.7443
#                 2.5669
#                -5.3906
#                -3.6293
#                -0.6910
#                 2.3495
#                -0.2689
#                -4.8533
#                 0.6559
#                -0.0533
#                -1.9814
#                 2.9998
#                -5.3930
#                -5.4611
#                -1.9563
#                -0.3893
#                -2.4429
#                -3.7985
#                 2.2072
#                -0.8583
#                 3.4079
#                 0.8792
#                -4.1237
#                -4.6254
#                 3.2917
#                 5.4129
#                -2.7629
#                 0.0188
#                 0.0285
#                 2.2604
#                 1.1205
#                 3.8732
#                -5.8408
#                 0.3941
#                -3.7109
#                 2.3413
#                -4.8855
#                -3.0785
#                -0.5897
#                -3.2585
#                -0.0583
#                -0.2092
#                 1.6389
#               [torch.FloatTensor of size 120]), ('fc2.weight',
#                4.5122e-02 -1.9212e-02  2.3623e-02  ...   1.2385e-02  5.1609e-02  8.3232e-02
#               -4.6514e-02 -9.8117e-02  7.0517e-02  ...   4.2968e-02 -3.7835e-02 -2.2132e-02
#                3.7627e-02  8.0007e-02  4.6196e-02  ...  -7.8948e-02  8.9965e-02  7.0560e-02
#                               ...                   ⋱                   ...
#               -1.8402e-02 -2.3397e-02 -7.5845e-02  ...  -5.7369e-02 -3.0761e-02  6.8396e-02
#               -2.8112e-02 -3.8216e-02 -8.9286e-02  ...   1.6891e-02 -4.4540e-03  2.4147e-02
#               -5.8487e-02  1.5708e-04 -6.8370e-02  ...   3.3812e-02  8.3482e-02 -8.2003e-02
#               [torch.FloatTensor of size 84x120]), ('fc2.bias',
#               1.00000e-02 *
#                -7.0687
#                -4.7535
#                -7.0068
#                 4.6739
#                -8.0093
#                 1.6817
#                 6.8430
#                -8.7656
#                 0.4579
#                -9.6698
#                 4.3429
#                 7.9224
#                 2.3357
#                -3.1849
#                 0.3646
#                -7.5931
#                 6.0172
#                -8.4304
#                -9.6337
#                 6.0601
#                -8.9957
#                -4.9662
#                -4.7972
#                 1.7719
#                -0.4624
#                 4.3865
#                 8.0653
#                 4.4026
#                -5.7741
#                 5.4975
#                 2.8582
#                 2.9388
#                 2.8539
#                 4.3106
#                 5.7194
#                -7.4802
#                 3.3866
#                -9.0517
#                -5.6919
#                -7.5029
#                -3.3123
#                -1.1662
#                -7.6688
#                -4.4699
#                 2.6436
#                 7.6340
#                 4.2800
#                 0.6639
#                -0.0911
#                 5.3262
#                 8.3596
#                -8.9787
#                 3.0214
#                -8.5407
#                -6.8001
#                 2.4034
#                -4.0214
#                -2.1202
#                 1.4124
#                 6.0341
#                 4.5992
#                 1.1765
#                -4.4585
#                 6.1645
#                 7.1358
#                -3.3900
#                -3.0449
#                -9.3157
#                -7.2892
#                 2.7775
#                 1.0949
#                -3.8185
#                 8.4572
#                -5.5296
#                 3.6449
#                -0.3034
#                -2.0261
#                -1.9028
#                 7.1602
#                -1.7002
#                 1.6339
#                -6.7994
#                -1.8505
#                 3.5538
#               [torch.FloatTensor of size 84]), ('fc3.weight',
#
#               Columns 0 to 9
#                0.0912 -0.0046 -0.0779 -0.0257  0.0188  0.0451 -0.0804  0.0302 -0.1081 -0.0877
#                0.0001  0.0335  0.0219  0.0747 -0.1025 -0.0592  0.0022  0.0995 -0.0519 -0.0513
#               -0.0758 -0.0752  0.0333  0.0493  0.1079 -0.0088  0.0887  0.0107 -0.0070 -0.1001
#                0.0257 -0.0645  0.0431 -0.0520 -0.0294 -0.0903 -0.0259 -0.0375  0.0916 -0.1101
#               -0.0756  0.0637  0.0053  0.0419  0.0946  0.0603 -0.0857 -0.0132  0.0074 -0.0312
#               -0.0497  0.0218  0.0373 -0.0835 -0.0541  0.0840  0.0121 -0.0296 -0.0532  0.0235
#               -0.0412  0.0238 -0.1055  0.0311  0.0722  0.0778 -0.0869 -0.0014  0.0388  0.0876
#                0.0948  0.0598  0.0684 -0.0180 -0.0935  0.0593 -0.0280  0.1072 -0.0670 -0.0298
#                0.0316  0.0569  0.0101  0.0990 -0.0104  0.0220  0.0680  0.0829  0.0183  0.0174
#                0.0811  0.0783  0.0429 -0.0669  0.0385 -0.1155  0.0050  0.0520 -0.0925 -0.0662
#
#               Columns 10 to 19
#               -0.1127 -0.0917  0.0290  0.0901 -0.1016  0.0099  0.0786 -0.1033 -0.0570 -0.1184
#               -0.0765  0.1034  0.1066  0.1039  0.0756 -0.0067 -0.0013 -0.0810 -0.0047 -0.0809
#               -0.0606  0.0042 -0.0137 -0.0987 -0.0305  0.0101 -0.0029 -0.0590 -0.0147 -0.1017
#                0.1108 -0.0413 -0.0104 -0.0086 -0.1089 -0.0252  0.0168  0.0141 -0.0130 -0.0394
#               -0.0927  0.0678  0.0950 -0.0384 -0.0215 -0.0889 -0.0986 -0.1140 -0.0129 -0.0241
#               -0.0012  0.0707  0.0411  0.0620 -0.0842 -0.1039 -0.0436  0.0710 -0.0367 -0.0917
#                0.0450 -0.0436 -0.1133  0.0561  0.0187 -0.0164 -0.0827 -0.0891  0.0080 -0.0559
#               -0.0178  0.0770  0.0475  0.0823  0.0703 -0.0952 -0.0403 -0.0796 -0.0495  0.0594
#               -0.0816 -0.0669 -0.0324  0.0727  0.0246  0.0623 -0.1001 -0.0568 -0.0071  0.0821
#                0.0668 -0.0813  0.0246  0.0610 -0.1071 -0.0056  0.0156 -0.0043  0.0231 -0.0372
#
#               Columns 20 to 29
#               -0.0676 -0.0703  0.0959 -0.0787 -0.0773  0.0899 -0.0820 -0.0783 -0.0684  0.0832
#                0.0563 -0.0506  0.0449 -0.0084 -0.0574  0.1106  0.1132  0.0623  0.0238 -0.0381
#                0.0689 -0.0748  0.0024 -0.0146 -0.0434 -0.1024  0.0846  0.0490 -0.0440 -0.0711
#               -0.0898  0.0885 -0.0610  0.0379  0.0712 -0.0097 -0.0501  0.1032 -0.0070  0.0636
#                0.0092 -0.0624 -0.0125  0.0614 -0.0832 -0.0262 -0.0433  0.0007  0.0392 -0.0480
#               -0.0134  0.0181  0.0953  0.0749 -0.0845 -0.0252  0.0583 -0.1030 -0.0853 -0.0213
#                0.0841 -0.0818  0.0270  0.0089  0.0364  0.0808 -0.0670 -0.0397  0.0927  0.0091
#               -0.0840  0.0710 -0.0931  0.0927 -0.0031  0.0454 -0.0851  0.0636 -0.0382  0.0755
#               -0.0417  0.0634  0.0860 -0.0967 -0.0485 -0.0523  0.0338 -0.0538  0.0142 -0.0629
#               -0.0184 -0.0369  0.1026  0.0475  0.0078  0.0058 -0.0564 -0.0571 -0.0542 -0.0759
#
#               Columns 30 to 39
#                0.0689 -0.1079  0.0204  0.0567  0.0216  0.0304  0.0768 -0.0418  0.0433  0.0275
#               -0.0113  0.0250  0.0215  0.0468 -0.0361  0.0226 -0.0255 -0.0745 -0.0844 -0.0401
#               -0.0695  0.0070  0.0842 -0.0605 -0.0050  0.0401  0.0942  0.0833  0.1137 -0.0067
#               -0.0270 -0.0507  0.1030 -0.0394 -0.0699 -0.0131  0.0011  0.0984  0.0574  0.0575
#               -0.0319 -0.0174  0.0289 -0.0707 -0.0482 -0.0898  0.0064 -0.0794 -0.0996  0.0356
#                0.0484 -0.0733  0.0662  0.0198  0.0984  0.0963 -0.0806 -0.0317 -0.0076 -0.0029
#               -0.0226  0.0119 -0.0259 -0.0961  0.0010  0.0030 -0.0489 -0.0145 -0.0653 -0.0865
#               -0.0257  0.0764 -0.0877 -0.1272  0.0634 -0.0761 -0.1093 -0.0303  0.0730 -0.0156
#               -0.0459  0.0115 -0.0635 -0.0021 -0.0963  0.0962  0.0735 -0.0085  0.0107  0.0884
#                0.0429  0.0666  0.0915  0.1142  0.0740 -0.0932 -0.0961 -0.0332 -0.0936 -0.0497
#
#               Columns 40 to 49
#               -0.0298  0.0540  0.0812 -0.0221 -0.0373  0.0887 -0.0937 -0.0251  0.0288 -0.0489
#                0.1032  0.0645 -0.1057 -0.0673 -0.0903  0.0135 -0.0030 -0.0016  0.0286 -0.0943
#                0.0122 -0.0407  0.0962 -0.0280  0.0853 -0.0105 -0.0589  0.0862  0.0844 -0.0224
#                0.0780 -0.0700 -0.0329  0.0463 -0.0008  0.0162 -0.0433 -0.0798  0.0581 -0.0753
#                0.0912  0.0925 -0.0927 -0.0457 -0.0299  0.0542 -0.0295  0.1089  0.0502 -0.0752
#                0.0208  0.0404 -0.1023  0.0941 -0.0080  0.0531  0.0113 -0.0448  0.0724 -0.0855
#                0.0833 -0.0094 -0.0445 -0.0149  0.0763  0.0895 -0.0824  0.0826  0.0852 -0.0147
#               -0.0528 -0.0721 -0.0551 -0.0874  0.0311 -0.0472 -0.0839 -0.0760 -0.0294  0.0455
#                0.0412 -0.0231  0.0403  0.0985  0.0314 -0.0196  0.0007 -0.0406  0.0565  0.0726
#               -0.1050  0.0844  0.0076 -0.0998 -0.1051  0.0301  0.0356  0.0831  0.0700 -0.0277
#
#               Columns 50 to 59
#                0.0394 -0.0537  0.0145  0.0819  0.0805  0.0058 -0.0194  0.0627 -0.0971  0.0200
#                0.0776 -0.1006  0.0326  0.0884  0.0197 -0.0817  0.0013 -0.0456  0.0092  0.0413
#               -0.0410  0.0626 -0.0179  0.0817  0.0129 -0.0984  0.0850 -0.1035 -0.0612  0.0212
#                0.0576 -0.0466  0.0657 -0.0898  0.0676  0.0795  0.0127 -0.0290 -0.0604  0.0883
#                0.0680  0.0622  0.0141 -0.0479  0.0435  0.0144 -0.0065  0.0394 -0.0865  0.0329
#                0.0394  0.1075 -0.0252  0.1028  0.0818 -0.0725 -0.0381 -0.0830 -0.0932  0.0258
#                0.0724  0.0032  0.0059 -0.0192 -0.0968  0.0622 -0.0366  0.0013  0.0642  0.0073
#                0.0517  0.0519  0.0654  0.0536 -0.0315  0.0379 -0.0997 -0.0832  0.0422 -0.0157
#               -0.0240  0.0976 -0.0189 -0.0835 -0.0915 -0.0284  0.1004 -0.0614  0.0757 -0.1044
#               -0.0703  0.0603 -0.0584  0.0074 -0.0348  0.0295 -0.0689 -0.0905  0.0072 -0.0695
#
#               Columns 60 to 69
#                0.0855 -0.0309 -0.0058  0.0368 -0.0324 -0.0309 -0.0733 -0.1149 -0.0836  0.0308
#               -0.0484 -0.0293 -0.0035  0.0318 -0.0500 -0.0305  0.0619 -0.1039 -0.0032  0.0444
#               -0.0505 -0.0262 -0.0999 -0.1171 -0.0150  0.0672 -0.0267  0.0809 -0.1028 -0.1035
#               -0.0385 -0.0798 -0.0377  0.0541  0.0947  0.0933  0.0769  0.0381  0.0953 -0.0875
#               -0.0963  0.0690  0.0057 -0.1173  0.0537  0.0210 -0.0353 -0.0605 -0.0237 -0.0081
#               -0.0780  0.0394 -0.0953  0.0251 -0.0017  0.0610  0.0123  0.0175 -0.0200  0.0345
#                0.0179  0.0186  0.0669  0.0402  0.0590 -0.0192 -0.0209 -0.0805 -0.0185 -0.1024
#                0.0071  0.0794 -0.0766  0.0666  0.0979 -0.0670  0.0695  0.0780  0.0790  0.0078
#                0.0559 -0.0082  0.0122 -0.0152 -0.0956 -0.0505 -0.0132 -0.0208  0.0438 -0.0320
#               -0.0672  0.0804 -0.1031  0.0653  0.0353  0.0476 -0.0894 -0.0160  0.0744 -0.0068
#
#               Columns 70 to 79
#                0.0789  0.0190 -0.0244  0.0875  0.0163  0.0465 -0.0129 -0.0834  0.0330 -0.0668
#                0.0348  0.0313  0.0550 -0.0780  0.1031 -0.0565  0.0088 -0.0159  0.0981 -0.0296
#                0.0433  0.0788 -0.0197  0.0067 -0.0767  0.0455 -0.0816  0.0306  0.0618 -0.0110
#               -0.0836 -0.0653  0.0454 -0.0212 -0.0820 -0.0481  0.0199  0.0656  0.1003  0.0031
#                0.0821 -0.0650 -0.0039 -0.0918 -0.0717  0.0018  0.0066 -0.0510 -0.0550 -0.0347
#                0.0141  0.0261  0.0711 -0.0455 -0.0565 -0.0500 -0.0053  0.0709  0.0538  0.0281
#                0.0573  0.0387 -0.1120 -0.0814 -0.0613 -0.0501  0.0175 -0.0799  0.0897 -0.0791
#               -0.0004 -0.0912  0.0654 -0.0068 -0.0011 -0.1146 -0.1071  0.0209 -0.0896  0.0346
#               -0.0776 -0.1041 -0.1050 -0.0920 -0.0245 -0.0317  0.0737 -0.0854  0.0571 -0.0238
#                0.0021 -0.0562  0.0981 -0.0860 -0.0253 -0.1210 -0.0154  0.0459  0.0477  0.0747
#
#               Columns 80 to 83
#               -0.1164  0.0625 -0.0626  0.0112
#               -0.0773 -0.0804  0.0316 -0.0860
#                0.0060  0.0116 -0.0820 -0.0685
#                0.0384 -0.0803  0.0153 -0.0991
#                0.0594  0.0719 -0.0404  0.0610
#                0.0795  0.0353  0.1007  0.0312
#                0.0648 -0.0650 -0.1008  0.0765
#               -0.0577 -0.0013 -0.0329 -0.0308
#               -0.0798  0.0460  0.0892  0.0780
#               -0.0670 -0.0211  0.0344  0.0776
#               [torch.FloatTensor of size 10x84]), ('fc3.bias',
#               1.00000e-02 *
#                 1.4799
#                -1.6765
#                 4.6587
#                -8.6934
#                 5.2477
#                -2.4838
#                 6.7397
#                 9.1037
#                 9.6035
#                -1.1453
#               [torch.FloatTensor of size 10])])
